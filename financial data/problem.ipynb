# %%
import mplfinance as mpf
import yfinance as yf

# %%
data1=yf.download('TSLA',start='2024-01-01',end='2024-01-31')
data2=yf.download('AMZN',start='2024-02-01',end='2024-02-27')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import pandas as pd
data3=pd.concat([data1,data2])
data3
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  250.080002  251.250000  244.410004  248.419998  248.419998
# 2024-01-03  244.979996  245.679993  236.320007  238.449997  238.449997
# 2024-01-04  239.250000  242.699997  237.729996  237.929993  237.929993
# 2024-01-05  236.860001  240.119995  234.899994  237.490005  237.490005
# 2024-01-08  236.139999  241.250000  235.300003  240.449997  240.449997
# 2024-01-09  238.110001  238.960007  232.039993  234.960007  234.960007
# 2024-01-10  235.100006  235.500000  231.289993  233.940002  233.940002
# 2024-01-11  230.570007  230.929993  225.369995  227.220001  227.220001
# 2024-01-12  220.080002  225.339996  217.149994  218.889999  218.889999
# 2024-01-16  215.100006  223.490005  212.179993  219.910004  219.910004
# 2024-01-17  214.860001  215.669998  212.009995  215.550003  215.550003
# 2024-01-18  216.880005  217.449997  208.740005  211.880005  211.880005
# ...

# %%
mpf.plot(data3,type='candle',style='yahoo')

# %%
ticker_obj=yf.Ticker('TSLA')

# %%
d=ticker_obj.get_income_stmt()
d
# Out:
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                    14796000000.0
# TotalUnusualItems                                             0.0
# TotalUnusualItemsExcludingGoodwill                            0.0
# NetIncomeFromContinuingOperationNetMinorityInte...  14999000000.0
# ReconciledDepreciation                               4667000000.0
# ReconciledCostOfRevenue                             79113000000.0
# EBITDA                                              14796000000.0
# EBIT                                                10129000000.0
# NetInterestIncome                                     910000000.0
# InterestExpense                                       156000000.0
# InterestIncome                                       1066000000.0
# ...

# %%
print(d)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
