# %%
import pandas as pd
sp500 = pd.read_csv("sp500.csv")
sp500['Price'].plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
sp500.Sector.value_counts().plot(kind="bar", figsize=(10,6), title="Bar chart of sp500 stocks")
# Out:
# <AxesSubplot:title={'center':'Bar chart of sp500 stocks'}>

# %%
sp500.plot(
    x = "Price",
    y = "Sector",
    kind = "scatter",
    figsize = (8, 5),
    title = "Cost vs Price"
)
# Out:
# <AxesSubplot:title={'center':'Cost vs Price'}, xlabel='Price', ylabel='Sector'>

# %%
stock_price=pd.read_csv("stock_value.csv", parse_dates=["Date"], index_col="Date")
stock_price
stock_price.plot(
    kind = "line",
    figsize = (10, 6),
)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib
import mplfinance
